# %%
# !apt-get install python3.7
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.7 is already the newest version (3.7.10-1+bionic3).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %%
# !pip install spacy==2.1.0
# !pip install neuralcoref
# !pip install https://github.com/explosion/spacy-models/releases//download/en_core_web_lg-2.1.0/en_core_web_lg-2.1.0.tar.gz

import pandas as pd
import re
import spacy
import neuralcoref
import en_core_web_lg
import torch

nlp = en_core_web_lg.load()
neuralcoref.add_to_pipe(nlp)
# Out:
# ...
#      |████████████████████████████████| 826.9MB 22kB/s
# ...
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.1.0-cp37-none-any.whl size=828255077 sha256=6f25c13bea385a3b9342a94fc51ffdd4d6ab850bd07998aaf25ac0fd8a42665e
#   Stored in directory: /root/.cache/pip/wheels/f5/23/48/c3271dd3a62b4dbe0edc676eca71ca861cf8d985675438d3dc
# Successfully built en-core-web-lg
# ...
# 100%|██████████| 40155833/40155833 [00:00<00:00, 47010600.32B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
doc2 = nlp('Angela lives in Boston. She is quite happy in that city.')

# %%
for ent in doc2.ents:
    print(ent._.coref_cluster)
# Out:
# Angela: [Angela, She]
# Boston: [Boston, that city]

# %%
cd ..
# Out:
# /

# %%
# !bash ./content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/compile_coref_data.sh friends.train.episode_delim.conll
# Out:
# Streaming output truncated to the last 5000 lines.
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0276.v4_gold_prop
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0276.v4_gold_sense
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0276.v4_gold_skel
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0277.v4_auto_skel
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0277.v4_gold_prop
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0277.v4_gold_sense
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0277.v4_gold_skel
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0278.v4_auto_skel
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0278.v4_gold_prop
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0278.v4_gold_sense
# conll-2012/v4/data/train/data/arabic/annotations/nw/ann/02/ann_0278.v4_gold_skel
# ...

# %%
neuralcoref\train\conllparser.py --path content\drive\MyDrive\neuralcoref\neuralcoref\neuralcoref\train\
# Out:
#   File "<ipython-input-54-4822df05c60c>", line 1
#     neuralcoref\train\conllparser --path content\drive\MyDrive\neuralcoref\neuralcoref\neuralcoref\train
#                                                                                                         ^
# SyntaxError: unexpected character after line continuation character

# %%
cd /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script
# Out:
# /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script

# %%
pwd
# Out:
# '/content/drive/My Drive/neuralcoref/neuralcoref/neuralcoref/train'

# %%
cd ..
# Out:
# /content/drive/My Drive/neuralcoref/neuralcoref/neuralcoref/train

# %%
# !python -m conllparser --path ./conll_processing_script/conll-2012/v4/data/train/
# Out:
# Loading embeddings from /content/drive/My Drive/neuralcoref/neuralcoref/neuralcoref/train/weights/static_word
# Loading embeddings from /content/drive/My Drive/neuralcoref/neuralcoref/neuralcoref/train/weights/tuned_word
# 🌋 Reading files
# In ./conll_processing_script/conll-2012/v4/data/train/ /content/drive/My Drive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/train
# In ./conll_processing_script/conll-2012/v4/data/train/data /content/drive/My Drive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/train/data
# In ./conll_processing_script/conll-2012/v4/data/train/data/english /content/drive/My Drive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/train/data/english
# ...

# %%
# !python -m conllparser --path ./conll_processing_script/conll-2012/v4/data/test/
# Out:
# Loading embeddings from /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/weights/static_word
# Loading embeddings from /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/weights/tuned_word
# 🌋 Reading files
# In ./conll_processing_script/conll-2012/v4/data/test/ /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/test
# In ./conll_processing_script/conll-2012/v4/data/test/data /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/test/data
# In ./conll_processing_script/conll-2012/v4/data/test/data/english /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/test/data/english
# In ./conll_processing_script/conll-2012/v4/data/test/data/english/annotations /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/test/data/english/annotations
# ...

# %%
# !python -m conllparser --path ./conll_processing_script/conll-2012/v4/data/development/
# Out:
# Loading embeddings from /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/weights/static_word
# Loading embeddings from /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/weights/tuned_word
# 🌋 Reading files
# In ./conll_processing_script/conll-2012/v4/data/development/ /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/development
# In ./conll_processing_script/conll-2012/v4/data/development/data /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/development/data
# In ./conll_processing_script/conll-2012/v4/data/development/data/english /content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/conll_processing_script/conll-2012/v4/data/development/data/english
# ...

# %%
pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 122kB 28.8MB/s
# ...

# %%
# !python -m learn --train ./conll_processing_script/conll-2012/v4/data/train/ --eval ./conll_processing_script/conll-2012/v4/data/dev/
# Out:
# Namespace(all_pairs_epoch=200, all_pairs_l2=1e-06, all_pairs_lr=0.0002, batchsize=20000, checkpoint_file=None, conll_eval_interval=10, conll_train_interval=20, costfl=0.4, costfn=0.8, costs={'FN': 0.8, 'FL': 0.4, 'WL': 1.0}, costwl=1.0, cuda=True, eval='./conll_processing_script/conll-2012/v4/data/dev//numpy/', evalkey='./conll_processing_script/conll-2012/v4/data/dev//key.txt', h1=1000, h2=500, h3=500, lazy=True, log_interval=10, min_lr=2e-08, numworkers=8, on_eval_decrease='nothing', patience=3, ranking_epoch=200, ranking_l2=1e-05, ranking_lr=2e-06, save_path='/content/drive/MyDrive/neuralcoref/neuralcoref/neuralcoref/train/checkpoints/May19_20-23-24_e4f5fa2e7c48_', seed=1111, startstage=None, startstep=None, top_pairs_epoch=200, top_pairs_l2=1e-05, top_pairs_lr=0.0002, train='./conll_processing_script/conll-2012/v4/data/train//numpy/', trainkey='./conll_processing_script/conll-2012/v4/data/train//key.txt', weights=None)
# Training for 200 200 200 epochs
# ...
